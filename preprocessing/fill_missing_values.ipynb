# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.max_rows', None)

# %%
cellphones = pd.read_csv(r'..\crawling\cellphones\raw_data.csv', encoding='utf-8-sig')
tgdd = pd.read_csv(r'..\crawling\tgdd\raw_data.csv', encoding='utf-8-sig')

# %%
cellphones['operating_system'] = cellphones['operating_system'].replace(['Android 16', 'Android 17'], np.nan)

# %%
data = pd.concat([cellphones, tgdd], ignore_index=True)

# %% [markdown]
# # Xử lí dữ liệu trùng lắp

# %%
# Kiểm tra duplicate trong dữ liệu
data.duplicated().sum()
# Out:
# 1292

# %% [markdown]
# Một số máy có thông số giống nhau hoàn toàn -> Drop.

# %%
# Drop các dòng bị duplicated trong dữ liệu
data.drop_duplicates(inplace=True)

# %% [markdown]
# # Xử lí các dữ liệu rỗng

# %%
# Tìm các dòng rỗng hoàn toàn (tất cả các cột đều là NaN)
empty_rows = data.isnull().all(axis=1)
print(empty_rows.sum())
# Out:
# 1

# %%
# Drop các dòng rỗng hoàn toàn trong dữ liệu
data.drop(index=data[pd.Series(empty_rows).values].index, inplace=True)

# %% [markdown]
# Thuộc tính price_old là thuộc tính rất quan trọng, được xem là target của bài toán -> Drop các dòng bị thiếu thuộc tính price_old

# %%
# Loại bỏ các dòng bị thiếu giá trị trong cột 'price_old'
data = data.dropna(subset=['price_old'])

# %% [markdown]
# # Xử lí cột name, brand

# %%
print(data['name'].unique())
# Out:
# ['iPhone 14 Pro Max 128GB' 'iPhone 13 Pro Max 128GB'
#  'OPPO Find N3 Flip 12GB 256GB' 'Samsung Galaxy S24 Plus 12GB 256GB'
#  'Samsung Galaxy S24 Ultra 12GB 256GB' 'iPhone 14 Pro Max 256GB'
#  'iPhone 14 Pro 128GB' 'iPhone 13 Pro Max 256GB' 'iPhone 15 Plus 128GB'
#  'Samsung Galaxy S23 Ultra 8GB 256GB' 'OPPO A78 8GB 256GB'
#  'OPPO Find N3 16GB 512GB' 'iPhone 15 Pro 128GB' 'iPhone 15 Pro Max 256GB'
#  'Samsung Galaxy S23 8GB 128GB'
#  'iPhone 16 Plus 128GB Chính hãng VN/A (3N350)' 'iPhone 11 64GB'
#  'iPhone 8 Plus 64GB cũ đẹp' 'iPhone 15 Pro 256GB'
#  'Samsung Galaxy S22 Ultra (12GB' 'iPhone XS Max 256GB Cũ đẹp'
#  'iPhone 12 Pro Max 128GB' 'Samsung Galaxy Z Fold5 12GB 512GB'
#  'Apple iPhone 7 Plus 128GB' 'Samsung Galaxy M55 (12GB 256GB)'
#  'iPhone 14 128GB' 'iPhone XS Max 64GB Cũ trầy xước' 'iPhone 11 128GB'
#  'iPhone 16 Pro Max 256GB | Chính hãng VN/A' 'iPhone 15 128GB'
#  'iPhone 14 Plus 128GB' 'iPhone 13 256GB'
#  'Samsung Galaxy A35 5G 8GB 128GB' 'iPhone 12 Pro Max 256GB'
#  'iPhone 14 Pro 256GB' 'iPhone 12 Pro 128GB Cũ đẹp'
#  'iPhone 15 128GB | Chính hãng (VN/A)' 'iPhone 16 Pro Max 256GB'
#  'vivo Y18S 6GB 128GB' 'iPhone 16 Pro 128GB | Chính hãng VN/A'
#  'realme Note 60 4GB 64GB' 'Xiaomi Redmi Note 14 5G 8GB 256GB'
#  'iPhone 15 Pro Max 512GB' 'iPhone 13 mini 128GB'
#  'iPhone 16 256GB | Chính hãng VN/A' 'iPhone 11 Pro 64GB cũ đẹp'
#  'iPhone 12 Pro 128GB' 'Apple iPhone 8 Plus 64GB Cũ Trầy xước'
#  'iPhone X 256GB Cũ trầy xước' 'iPhone 14 Pro Max 512GB'
#  'iPhone 11 Pro 256GB Cũ đẹp' 'Apple iPhone 7 Plus 32GB'
#  'Apple iPhone 8 64GB cũ' 'iPhone 11 Pro 512GB Cũ' 'iPhone 13 Pro 128GB'
#  'iPhone 12 Pro 256GB' 'iPhone XS Max 512GB Cũ trầy xước'
#  'Vivo V27e 8GB 256GB' 'iPhone 13 Pro 512GB' 'iPhone 13 128GB'
#  'iPhone 12 128GB' 'iPhone XS 256GB Cũ trầy xước' 'iPhone 12 mini 128GB'
#  'Samsung Galaxy A56 5G 8GB 128GB' 'iPhone 16 Pro Max 256GB 2 SIM'
#  'iPhone SE 2020 64GB Cũ đẹp' 'iPhone 15 Plus 256GB' 'Xiaomi 13 8GB 256GB'
#  'iPhone 15 Plus 128GB | Chính hãng VN/A'
#  'Samsung Galaxy A55 5G 8GB 128GB' 'Samsung Galaxy Z Fold4 12GB 256GB'
#  'OPPO Find X8 16GB 512GB' 'iPhone XS 256GB Cũ đẹp'
#  'Samsung Galaxy S23 Ultra 12GB 512GB' 'Xiaomi POCO X6 Pro 5G 8GB 256GB'
#  'Samsung Galaxy S21 FE 8GB 128GB' 'iPhone 13 VN/A 128GB'
#  'iPhone 8 Plus 128GB cũ đẹp' 'Samsung Galaxy A73 5G 8GB 128GB'
#  'iPhone 16 Plus 128GB' 'Apple iPhone 8 Plus 256GB cũ đẹp'
#  'Samsung Galaxy S24 Ultra 12GB 512GB'
#  'Samsung Galaxy S24 FE 5G 8GB 128GB' 'iPhone 12 mini 64GB Cũ đẹp'
#  'Samsung Galaxy S23 FE 5G 8GB 128GB'
#  'Điện thoại Nubia Music NFC 4GB 128GB (Bản đặc biệt)'
#  'iPhone 16 Pro 128GB' 'iPhone 11 Pro Max 512GB' 'iPhone 12 Pro Max 512GB'
#  'Nubia Neo 2 8GB 256GB' 'Samsung Galaxy Z Fold6 5G 256GB'
#  'iPhone 14 128GB | Chính hãng VN/A'
#  'Samsung Galaxy S25 Ultra 5G 12GB 256GB' 'iPhone 14 Plus 256GB'
#  'Samsung Galaxy A36 5G 8GB 128GB' 'iPhone 14 Pro Max 512GB 2 SIM'
#  'iPhone 12 64GB' 'Samsung Galaxy Z Flip6 5G 256GB'
#  'Apple iPhone 7 Plus 256GB' 'Samsung Galaxy A54 5G 8GB 128GB'
#  'iPhone XS 64GB Cũ trầy xước'
#  'Xiaomi Redmi Note 14 Pro Plus 5G 8GB 256GB' 'iPhone 12 256GB'
#  'OPPO Find N2 Flip 8GB 256GB' 'iPhone 15 256GB | Chính hãng VN/A'
#  'Samsung Galaxy S23 Ultra' 'Realme C55 8GB 256GB'
#  'Samsung Galaxy A05S 6GB 128GB' 'iPhone 15 Pro 512GB'
#  'iPhone 11 Pro Max 512GB Cũ trầy xước' 'iPhone 11 Pro 64GB'
#  'Samsung Galaxy Z Flip4 128GB' 'Xiaomi 15 Ultra 5G 16GB 512GB'
#  'OPPO Reno12 F 5G 8GB 256GB' 'Xiaomi 13T 12GB 256GB'
#  'iPhone 16 Plus 128GB | Chính hãng' 'iPhone XS Max 256GB Cũ trầy xước'
#  'OPPO Reno10 5G 8GB 256GB' 'iPhone 11 128GB Chính hãng'
#  'iPhone XR 128GB Cũ đẹp' 'Xiaomi Redmi Note 13 Pro 4G'
#  'Nothing Phone 2A 8GB 128GB' 'iPhone 13 mini 256GB'
#  'Tecno Pova 6 (8GB/256GB)' 'OPPO Reno12 5G 12GB 512GB'
#  'Samsung Galaxy Z Fold5 12GB 256GB' 'OPPO Reno12 5G 12GB 256GB'
#  'Infinix Note 40 Pro 8GB 256GB' 'Xiaomi Redmi Note 11 Pro Plus 5G'
#  'Samsung Galaxy S25 Ultra 5G 12GB 512GB' 'iPhone 12 Pro 512GB'
#  'Samsung Galaxy S25 5G 12GB 256GB' 'OPPO Reno11 5G 8GB 256GB'
#  'Xiaomi Redmi Note 13 Pro Plus 5G 8GB 256GB' 'iPhone 13 Pro 256GB'
#  'TECNO CAMON 40 Pro 8GB 256GB' 'iPhone 16 Pro Max 512GB'
#  'Xiaomi 13 Lite 8GB 256GB' 'OPPO Reno11 F 5G 8GB 256GB'
#  'Samsung Galaxy A53 (5G)' 'Samsung Galaxy S22 (8GB'
#  'iPhone 14 Pro Max 1TB' 'iPhone 15 512GB' 'Tecno Pova 6 Neo (8GB 128GB)'
#  'Samsung Galaxy Note 20 Ultra Cũ Xước Cấn'
#  'Samsung Galaxy S21 FE 6GB 128GB' 'OPPO Reno10 Pro Plus 5G'
#  'Samsung Galaxy A16 5G 8GB 128GB' 'Xiaomi 13 Pro 12GB 256GB'
#  'ASUS ROG Phone 5S 16GB 256GB' 'iPhone 14 Pro Max 256GB 2 Sim'
#  'Samsung Galaxy S24 8GB 256GB' 'TECNO SPARK 30 Pro 8GB 256GB'
#  'Samsung Galaxy S23 Plus 8GB 256GB' 'Samsung Galaxy A25 5G 6GB 128GB'
#  'Samsung Galaxy Z Flip5 256GB' 'iPhone 14 Pro Max 128GB 2 SIM'
#  'iPhone 16 Pro Max 512GB | Chính hãng VN/A'
#  'Điện thoại Sony Xperia 10V 8GB 128GB' 'iPhone 11 256GB'
#  'TECNO CAMON 30S 8GB 256GB' 'Samsung Galaxy S21 Ultra 5G 128GB'
#  'Samsung Galaxy S21 5G' 'Samsung Galaxy Z Fold4 5G 256GB'
#  'Điện thoại Meizu Mblu 21 4GB 64GB' 'Samsung Galaxy A23' 'iPhone XR 64GB'
#  'OPPO Find X5 Pro 5G 12GB 256GB' 'Samsung Galaxy S23 FE 5G 8GB 256GB'
#  'Samsung Galaxy S22 Plus (8GB' 'iPhone SE 2020 128GB'
#  'Điện thoại Meizu Mblu 21 6GB 128GB' 'iPhone XR 128GB Cũ trầy xước'
#  'Vivo Y36 8GB 128GB' 'ASUS ROG Phone 5S 8GB 128GB'
#  'realme 11 Pro 8GB 256GB' 'Vivo V25 Pro 5G 8GB 128GB'
#  'Điện thoại Itel RS4 8GB 128GB NFC' 'POCO M6 (6GB 128GB)'
#  'iPhone 13 512GB' 'Realme C53 8GB 256GB' 'Itel P55 Plus 8GB 128GB'
#  'iPhone 13 Pro Max 512GB' 'Samsung Galaxy S20 FE 256GB'
#  'Samsung Galaxy S25 Plus 5G 12GB 256GB'
#  'Nothing Phone 2A Plus 12GB 256GB'
#  'Samsung Galaxy Z Fold3 5G 256GB Cũ xước cấn'
#  'iPhone 12 64GB Chính Hãng (VN/A)' 'iPhone SE 2020 256GB'
#  'Samsung Galaxy Note 20' 'OPPO A79 5G 12GB 256GB'
#  'Samsung Galaxy A33 (5G)' 'OPPO A57 4GB 128GB'
#  'Samsung Galaxy A05 4GB 128GB' 'iPhone 14 Pro 512GB'
#  'iPhone 15 Pro Max 512GB | Chính hãng VN/A' 'iPhone 14 Pro 128GB 2 SIM'
#  'Samsung Galaxy A15 LTE 8GB 128GB' 'iPhone 15 Pro Max 256GB 2 SIM'
#  'Xiaomi 12' 'TECNO SPARK Go 1 4GB 64GB' 'Samsung Galaxy A06 4GB 128GB'
#  'POCO X5 5G 6GB 128GB' 'iPhone 12 mini 256GB Cũ đẹp'
#  'iPhone 13 mini 512GB' 'Xiaomi Redmi Note 13 Pro 8GB 256GB'
#  'Samsung Galaxy S22 Ultra (8GB' 'Realme C55 6GB 128GB'
#  'OPPO A17K 3GB 64GB' 'ASUS ROG Phone 6 16GB 512GB' 'vivo Y17s 4GB 128GB'
#  'OPPO A79 5G 8GB 256GB' 'Xiaomi Redmi 14C' 'vivo Y36 8GB 128GB'
#  'Oppo A16 3GB 32GB' 'iPhone 11 Pro Max 64GB 2 Sim'
#  'Xiaomi 12T Pro 12GB 256GB' 'Xiaomi 12T 8GB 128GB' 'Apple iPhone XR 64GB'
#  'Samsung Galaxy S21 Plus 5G' 'Nokia C20' 'iPhone 12 Pro Max 128GB 2 Sim'
#  'iPhone 14 Plus 256GB | Chính hãng VN/A'
#  'Samsung Galaxy A26 5G 8GB 128GB' 'iPhone 15 Pro Max 1TB'
#  'realme 13+ 5G (8GB 256GB)' 'Samsung Galaxy S21 FE 8GB 256GB'
#  'iPhone 15 Pro 1TB' 'OPPO Reno13 F 4G 8GB 256GB'
#  'iPhone 16 Plus 256GB | Chính hãng VN/A'
#  'Samsung Galaxy Z Fold5 12GB 512GB (F946)'
#  'Samsung Galaxy Note 20 Ultra 5G Cũ đẹp'
#  'Samsung Galaxy M34 5G 8GB 128GB' 'iPhone 16 Plus 256GB'
#  'iPhone 13 Pro Max 1TB' 'TECNO CAMON 40 8GB 128GB'
#  'Samsung Galaxy A06 5G 4GB 128GB' 'Samsung Galaxy Z Flip3 5G 128GB'
#  'Điện thoại Nubia V60 Design 6GB 256GB'
#  'Samsung Galaxy Z Fold3 5G 256GB Cũ trầy xước' 'OnePlus Nord CE 3 Lite'
#  'OnePlus 11 5G 16GB 256BGB' 'vivo V29E 8GB 256GB'
#  'Điện thoại Itel RS4 12GB 256GB NFC' 'Samsung Galaxy S25 Ultra 512GB'
#  'Xiaomi POCO X5 5G 6GB 128GB' 'OPPO Reno13 F 5G 12GB 256GB'
#  'Samsung Galaxy Z Flip3 5G 256GB'
#  'Samsung Galaxy Note 20 Ultra Cũ Trầy xước'
#  'Samsung Galaxy A34 5G 8GB 128GB' 'Xiaomi 12T' 'Xiaomi 14T 12GB 256GB'
#  'Samsung Galaxy S21 Plus 5G 256GB' 'OPPO A18 4GB 128GB'
#  'OPPO A58 4G 6GB 128GB' 'TECNO SPARK 30C 4GB 128GB' 'OPPO A3 6GB 128GB'
#  'TECNO CAMON 40 8GB 256GB' 'Vivo V23e 8GB 128GB'
#  'Điện thoại Tecno Camon 30 8GB/256GB' 'Xiaomi Redmi Note 9'
#  'OPPO Find X5 Pro' 'iPhone 12 Pro Max 256GB 2 Sim' 'OPPO A3 (8GB'
#  'iPhone 14 Plus 512GB' 'Samsung Galaxy A54 5G 8GB 256GB'
#  'Samsung Galaxy Note 20 Ultra 5G'
#  'Xiaomi Redmi Note 13 Pro Plus 5G 12GB 256GB' 'iPhone 16 256GB'
#  'Samsung Galaxy Z Flip4 256GB' 'Nubia Neo 2'
#  'Samsung Galaxy S24 Plus 12GB 512GB'
#  'Samsung Galaxy S21 Ultra 5G 12GB 128GB'
#  'Samsung Galaxy A73 5G 8GB 256GB' 'vivo V30E 12GB 256GB'
#  'Samsung Galaxy S23 Ultra 12GB 1TB' 'Realme C11 2GB 32GB 2021'
#  'Samsung Galaxy Z Flip6 12GB 512GB' 'TECNO SPARK 20PRO+'
#  'Realme C35 4GB 64GB' 'Điện thoại Itel RS4 8GB 256GB'
#  'Samsung Galaxy Z Fold6 12GB 512GB' 'Nokia C20 2GB 16GB'
#  'OPPO Reno8 Pro 5G 12GB 256GB' 'Samsung Galaxy S21 Plus 5G 8GB 128GB'
#  'OPPO A77s' 'OPPO Reno13 F 5G 12GB 512GB'
#  'iPhone 11 Pro Max 64GB 2 Sim Cũ đẹp'
#  'Xiaomi Redmi Note 12 Pro 4G 8GB 256GB' 'Samsung Galaxy S24 8GB 512GB'
#  'Samsung Galaxy Z Fold4 5G 512GB' 'Samsung Galaxy Z Flip4 5G 256GB'
#  'Samsung Galaxy Z Fold5 5G 512GB' 'OPPO Reno11 Pro 5G'
#  'Xiaomi Redmi Note 11 Pro 5G' 'iPhone 15 Plus 256GB 2 Sim'
#  'Samsung Galaxy Z Fold4 512GB' 'INOI 288S 4G'
#  'Apple iPhone 11 64GB 2 SIM Cũ đẹp' 'Tecno Camon 30 8GB 256GB'
#  'iPhone 13 Pro 1TB' 'Samsung Galaxy S24 Ultra 12GB 1TB'
#  'iPhone 15 Plus 512GB' 'Samsung Galaxy S23 8GB 256GB'
#  'Meizu Mblu 21 4GB 64GB' 'iPhone XS Max 64GB 2 SIM Cũ đẹp'
#  'iPhone 13 128GB 2 Sim' 'OPPO A98 8GB 256GB' 'Infinix Note 30 8GB 256GB'
#  'Điện thoại Tecno Camon 30 12GB/256GB' 'realme 11 8GB 128GB'
#  'iPhone 11 128GB 2 Sim Cũ' 'Samsung Galaxy Z Fold3 5G 512GB'
#  'Tecno Camon 30 12GB 256GB' 'OnePlus 11 5G 8GB 128GB' 'OPPO A38'
#  'OnePlus 8T 5G' 'OPPO A38 4GB 128GB' 'Vivo Y100'
#  'Samsung Galaxy A35 5G 8GB 256GB' 'Vivo Y16 8GB 256GB'
#  'Xiaomi Redmi Note 11 Pro' 'Samsung galaxy S23 Plus 8GB 512GB'
#  'OnePlus 11 16GB 256GB' 'Samsung Galaxy A14 6GB 128GB'
#  'iPhone 13 Pro Max 128GB 2 Sim' 'vivo V29E 12GB 256GB'
#  'Realme C35 4GB 128GB' 'Điện thoại ZTE Blade A55 4GB 64GB'
#  'Samsung Galaxy S24 12GB 256GB' 'Samsung Galaxy Z Flip4 512GB'
#  'Viettel T2 4G' 'Infinix Hot 40 Pro Free Fire 8GB 256GB'
#  'Samsung Galaxy A12' 'vivo Y03 4GB 128GB' 'vivo Y36 8GB 256GB'
#  'Điện thoại Itel P55 Plus NFC 8GB 256GB' 'Điện thoại BENCO V91 4GB 128GB'
#  'OPPO Reno12 F 5G 12GB 256GB' 'realme C61 (6GB 128GB)'
#  'realme C65 8GB 256GB' 'Điện thoại benco S1 Pro 8GB 256GB'
#  'OPPO A38 6GB 128GB' 'Samsung Galaxy Z Fold5 5G 1TB'
#  'iPhone 11 Pro Max 256GB 2 sim' 'Samsung Galaxy Z Fold4 5G 1TB'
#  'Samsung Galaxy A14 4GB 128GB' 'iPhone 15 Plus 128GB 2 SIM'
#  'Masstel izi T2 4G' 'Masstel Fami 60S 4G' 'OPPO Reno7 (5G)'
#  'iPhone 11 128GB 2 Sim' 'Masstel Izi 30 4G'
#  'Xiaomi Mi 11 Lite 4G 8G 128G' 'Xiaomi 14T' 'iPhone 14 256GB'
#  'Samsung Galaxy Z Fold3 5G 256GB' 'Nubia RedMagic 8S Pro 5G 12GB 256GB'
#  'Samsung Galaxy Note 10+ (Plus) cũ' 'Samsung Galaxy A05S 4GB 128GB'
#  'Apple iPhone XS Max 256GB Cũ Xước cấn' 'OPPO FIND N5 Fold 16GB 512GB'
#  'Xiaomi POCO X7 Pro 5G 12GB 256GB' 'Samsung Galaxy M14 5G 4GB 128GB'
#  'Xiaomi Redmi Note 12 4G 128GB' 'Samsung Galaxy A32 Cũ trầy xước'
#  'Nubia Neo 3 GT 12GB 256GB' 'Samsung Galaxy S21 Ultra 5G 256GB'
#  'Điện thoại Samsung Galaxy Z Flip5 5G 8GB/256GB'
#  'Điện thoại Samsung Galaxy Z Flip6 5G 12GB/512GB'
#  'Điện thoại HONOR X5 Plus 4GB/64GB' 'Điện thoại Mobell M239 4G'
#  'Điện thoại Samsung Galaxy Z Flip6 5G 12GB/256GB'
#  'Điện thoại Samsung Galaxy S24 5G 8GB/256GB'
#  'Điện thoại Samsung Galaxy A54 5G 8GB/128GB'
#  'Điện thoại Samsung Galaxy S24+ 5G 12GB/256GB'
#  'Điện thoại Samsung Galaxy S23 Ultra 5G 12GB/512GB'
#  'Điện thoại Xiaomi Redmi Note 13 Pro 5G 12GB/512GB'
#  'Điện thoại realme C65 8GB/128GB' 'Điện thoại OPPO Reno12 5G 12GB/512GB'
#  'Điện thoại realme Note 60 4GB/128GB' 'Điện thoại vivo V30e 5G 8GB/256GB'
#  'Điện thoại OPPO Find N3 Flip 5G 12GB/256GB Hồng'
#  'Điện thoại vivo Y03 4GB/128GB' 'Điện thoại vivo V30 5G 12GB/512GB'
#  'Điện thoại vivo V30e 5G 12GB/256GB' 'Điện thoại iPhone 13 256GB'
#  'Điện thoại OPPO A3 8GB/256GB' 'Điện thoại Samsung Galaxy A15 8GB/256GB'
#  'Điện thoại realme C53 8GB/256GB' 'Điện thoại realme C65 8GB/256GB'
#  'Điện thoại Nokia 220 4G' 'Điện thoại realme C65s 8GB/128GB'
#  'Điện thoại OPPO Reno12 5G 12GB/256GB Hồng' 'Điện thoại iPhone 12 128GB'
#  'Điện thoại iPhone 16 Pro 128GB' 'Điện thoại iPhone 15 Plus 256GB'
#  'Điện thoại Tecno Spark 20C 8GB/128GB'
#  'Điện thoại Xiaomi Redmi 14C 4GB/128GB'
#  'Điện thoại Xiaomi Redmi Note 13 8GB/256GB'
#  'Điện thoại Xiaomi Redmi Note 13 Pro 8GB/128GB'
#  'Điện thoại OPPO A3 6GB/128GB' 'Điện thoại HONOR X8b 8GB/512GB'
#  'Điện thoại iPhone 11 128GB' 'Điện thoại OPPO A3x 4GB/128GB'
#  'Điện thoại OPPO A3x 4GB/64GB' 'Điện thoại Xiaomi Redmi 13 8GB/128GB'
#  'Điện thoại iPhone 16 128GB' 'Điện thoại OPPO Reno12 F 8GB/256GB'
#  'Điện thoại Xiaomi Redmi A3 4GB/128GB' 'Điện thoại iPhone 16 512GB'
#  'Điện thoại HONOR X6b 6GB/128GB Tím' 'Điện thoại iPhone 15 512GB'
#  'Điện thoại iPhone 14 Plus 256GB' 'Điện thoại iPhone 16 Pro Max 256GB'
#  'Điện thoại OPPO A60 8GB/128GB' 'Điện thoại OPPO A3x 6GB/128GB'
#  'Điện thoại Nokia 110 4G Pro' 'Điện thoại iPhone 16 Pro 256GB'
#  'Điện thoại OPPO A3 8GB/128GB' 'Điện thoại OPPO A58 8GB/128GB'
#  'Điện thoại iPhone 16 Plus 128GB' 'Điện thoại iPhone 16 Pro Max 512GB'
#  'Điện thoại iPhone 16 Plus 256GB' 'Điện thoại realme Note 60 4GB/64GB'
#  'Điện thoại vivo Y03 4GB/64GB'
#  'Điện thoại HONOR X6b 6GB/128GB Đen/Xanh lá'
#  'Điện thoại iPhone 16 Plus 512GB' 'Điện thoại iPhone 14 256GB'
#  'Điện thoại iPhone 14 Plus 512GB' 'Điện thoại OPPO Reno13 F 5G 8GB/256GB'
#  'Điện thoại OPPO Reno13 F 5G 12GB/512GB'
#  'Điện thoại vivo V40 Lite 8GB/256GB'
#  'Điện thoại Samsung Galaxy A16 5G 8GB/256GB'
#  'Điện thoại vivo Y29 8GB/256GB' 'Điện thoại vivo Y29 8GB/128GB'
#  'Điện thoại Xiaomi 14T 5G 12GB/256GB'
#  'Điện thoại Xiaomi Redmi Note 14 5G 8GB/256GB'
#  'Điện thoại Samsung Galaxy A36 5G 8GB/128GB'
#  'Điện thoại Samsung Galaxy A16 4GB/128GB'
#  'Điện thoại OPPO A5 Pro 5G 8GB/256GB'
#  'Điện thoại OPPO Reno13 F 8GB/256GB'
#  'Điện thoại Xiaomi 15 Ultra 5G 16GB/512GB'
#  'Điện thoại OPPO Find X8 Pro 5G 16GB/512GB'
#  'Điện thoại OPPO Find X8 5G 16GB/512GB Hồng'
#  'Điện thoại realme 14 5G 12GB/256GB' 'Điện thoại vivo V50 Lite 8GB/256GB'
#  'Điện thoại vivo Y19s 4GB/128GB'
#  'Điện thoại Samsung Galaxy A06 5G 4GB/128GB' 'Điện thoại vivo Y16 128GB'
#  'Điện thoại realme 14T 5G 12GB/256GB'
#  'Điện thoại vivo V50 Lite 5G 8GB/256GB'
#  'Điện thoại Samsung Galaxy A56 5G 8GB/128GB'
#  'Điện thoại Xiaomi 15 Ultra 5G 16GB/512GB Trắng'
#  'Điện thoại Samsung Galaxy S25 5G 12GB/512GB'
#  'Điện thoại Samsung Galaxy A16 5G 8GB/128GB'
#  'Điện thoại HONOR X7c 8GB/256GB'
#  'Điện thoại Samsung Galaxy S25 Ultra 5G 12GB/1TB' 'Điện thoại vivo V25E'
#  'Điện thoại HONOR X8c 8GB/256GB'
#  'Điện thoại Xiaomi Redmi Note 14 6GB/128GB'
#  'Điện thoại Masstel S9 6GB/256GB' 'Điện thoại iPhone 16 Pro 512GB'
#  'Điện thoại HONOR X9c Smart 5G 12GB/256GB'
#  'Điện thoại HONOR X8c 8GB/512GB' 'Điện thoại HONOR X5b 4GB/64GB'
#  'Điện thoại Itel it9310' 'Điện thoại iPhone 16 Pro 1TB'
#  'Điện thoại Samsung Galaxy S25 Plus 5G 12GB/512GB'
#  'Điện thoại iPhone 16e 256GB' 'Điện thoại HONOR X9c 5G 12GB/256GB'
#  'Điện thoại Samsung Galaxy A26 5G 8GB/128GB'
#  'Điện thoại Samsung Galaxy S23+ 5G 256GB'
#  'Điện thoại iPhone 11 Pro Max 64GB' 'Điện thoại realme 14T 5G 8GB/256GB'
#  'Điện thoại Samsung Galaxy A53 5G 128GB'
#  'Điện thoại vivo V50 Lite 5G 12GB/256GB'
#  'Điện thoại Samsung Galaxy S23 5G 128GB' 'Điện thoại iPhone 11 Pro 256GB'
#  'Điện thoại realme 13+ 5G 8GB/256GB' 'Điện thoại Samsung Galaxy S20+'
#  'Điện thoại Samsung Galaxy S21 FE 5G (8GB/128GB)' 'Điện thoại vivo Y35'
#  'Điện thoại Tecno Spark 30 5G 6GB/128GB'
#  'Điện thoại Samsung Galaxy A23 5G 4GB'
#  'Điện thoại Samsung Galaxy A06 4GB/128GB'
#  'Điện thoại Nokia C31 (3GB/32GB)']

# %% [markdown]
# Cần loại bỏ các thông tin không cần thiết về cấu hình, tình trạng, chức năng. Chỉ giữ lại hãng và model điện thoại.

# %%
# Đổi kiểu dữ liệu thành str và chuyển thành chữ thường
data['name'] = data['name'].astype(str).str.lower()

# Xóa "điện thoại "
data['name'] = data['name'].str.replace(r'điện thoại ', '', regex=True)

# Loại bỏ các giá trị không hợp lệ
data = data.drop(data[data['name'] == 'false'].index)

# Xóa thông tin không cần thiết
pattern_to_remove = r'\s*(?:' \
                    r'\d+\s*gb' \
                    r'|\d+\s*ram' \
                    r'|\d+\s*rom' \
                    r'|\d+gb:\d+gb' \
                    r'|\d+:\d+' \
                    r'|cũ' \
                    r'|\d+\s*tb' \
                    r'|đã' \
                    r'|\b\d{4}\b' \
                    r'|2\s*sim' \
                    r'|\(' \
                    r'|chính' \
                    r'|nfc' \
                    r'|vn/a' \
                    r').*$'

data['name'] = data['name'].str.replace(pattern_to_remove, '', regex=True)

# Bổ sung hãng Apple cho các dòng iPhone
data['name'] = data['name'].str.replace(r'\bapple\b', '', regex=True, flags=re.IGNORECASE)
data['name'] = data['name'].str.replace(r'\biphone\b', 'apple iphone', regex=True, flags=re.IGNORECASE)

# Đồng bộ "+" thành "plus"
data['name'] = data['name'].str.replace(r'\s*\+\s*', ' plus ', regex=True)

# **Xóa khoảng trắng dư thừa **
data['name'] = data['name'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
data_name_unique = sorted(data['name'].dropna().unique())

for name in data_name_unique:
    print(name)

del data_name_unique
# Out:
# apple iphone 11
# apple iphone 11 pro
# apple iphone 11 pro max
# apple iphone 12
# apple iphone 12 mini
# apple iphone 12 pro
# apple iphone 12 pro max
# apple iphone 13
# apple iphone 13 mini
# apple iphone 13 pro
# apple iphone 13 pro max
# apple iphone 14
# apple iphone 14 plus
# apple iphone 14 pro
# apple iphone 14 pro max
# apple iphone 15
# apple iphone 15 plus
# apple iphone 15 pro
# apple iphone 15 pro max
# apple iphone 16
# apple iphone 16 plus
# apple iphone 16 pro
# apple iphone 16 pro max
# apple iphone 16e
# apple iphone 7 plus
# apple iphone 8
# apple iphone 8 plus
# apple iphone se
# apple iphone x
# apple iphone xr
# apple iphone xs
# apple iphone xs max
# asus rog phone 5s
# asus rog phone 6
# benco 4g g3
# benco s1 pro
# benco v91
# honor x5 plus
# honor x5b
# honor x5b plus
# honor x6b
# honor x7c
# honor x8b
# honor x8c
# honor x9c 5g
# honor x9c smart 5g
# infinix hot 40 pro free fire
# infinix note 30
# infinix note 40 pro
# inoi 288s 4g
# itel it2600
# itel it9211
# itel it9310
# itel p55 plus
# itel rs4
# masstel fami 50 4g
# masstel fami 60s 4g
# masstel izi 10
# masstel izi 30 4g
# masstel izi t2 4g
# masstel izi t6 4g
# masstel lux 10
# masstel s9
# meizu mblu 21
# mobell f209
# mobell f309 4g
# mobell m239 4g
# mobell m331 4g
# mobell m539
# mobell rock 4
# nokia
# nokia 105
# nokia 105 4g pro
# nokia 110 4g pro
# nokia 220 4g
# nokia c20
# nokia c31
# nokia hmd 105 4g
# nothing phone 2a
# nothing phone 2a plus
# nubia music
# nubia neo 2
# nubia neo 3 gt
# nubia redmagic 8s pro 5g
# nubia v60 design
# oneplus 11
# oneplus 11 5g
# oneplus 8t 5g
# oneplus nord ce 3 lite
# oppo a16
# oppo a17k
# samsung galaxy z flip4
# samsung galaxy z flip4 5g
# samsung galaxy z flip5
# samsung galaxy z flip5 5g
# samsung galaxy z flip6
# samsung galaxy z flip6 5g
# samsung galaxy z fold3 5g
# samsung galaxy z fold4
# samsung galaxy z fold4 5g
# samsung galaxy z fold5
# samsung galaxy z fold5 5g
# samsung galaxy z fold6
# samsung galaxy z fold6 5g
# sony xperia 10v
# tcl 406s
# tecno camon 30
# tecno camon 30s
# tecno camon 40
# tecno camon 40 pro
# tecno pova 6
# tecno pova 6 neo
# tecno spark 20c
# tecno spark 20pro plus
# tecno spark 30
# tecno spark 30 5g
# tecno spark 30 pro
# tecno spark 30c
# tecno spark go 1
# viettel sumo 4g t2
# viettel t2 4g
# vivo v23e
# vivo v25 pro 5g
# vivo v25e
# vivo v27e
# vivo v29e
# vivo v30 5g
# vivo v30e
# vivo v30e 5g
# vivo v40 5g
# vivo v40 lite
# vivo v50 lite
# vivo v50 lite 5g
# vivo y03
# vivo y04
# vivo y100
# vivo y16
# vivo y17s
# vivo y18
# vivo y18s
# vivo y19s
# vivo y28
# vivo y29
# vivo y35
# vivo y36
# xiaomi 12
# xiaomi 12t
# xiaomi 12t pro
# xiaomi 13
# xiaomi 13 5g
# xiaomi 13 lite
# xiaomi 13 pro
# xiaomi 13t
# xiaomi 14 5g
# xiaomi 14 ultra 5g
# xiaomi 14t
# xiaomi 14t 5g
# xiaomi 14t pro 5g
# xiaomi 15 5g
# xiaomi 15 ultra 5g
# xiaomi mi 11 lite 4g 8g 128g
# xiaomi poco x5 5g
# xiaomi poco x6 pro 5g
# xiaomi poco x7 pro 5g
# xiaomi redmi 13
# xiaomi redmi 13x
# xiaomi redmi 14c
# xiaomi redmi a3
# xiaomi redmi a5
# xiaomi redmi note 11 pro
# xiaomi redmi note 11 pro 5g
# xiaomi redmi note 11 pro plus 5g
# xiaomi redmi note 11s
# xiaomi redmi note 12 4g
# xiaomi redmi note 12 pro 4g
# xiaomi redmi note 12 pro 5g
# xiaomi redmi note 13
# xiaomi redmi note 13 pro
# xiaomi redmi note 13 pro 4g
# xiaomi redmi note 13 pro 5g
# xiaomi redmi note 13 pro plus 5g
# xiaomi redmi note 14
# xiaomi redmi note 14 5g
# xiaomi redmi note 14 pro
# xiaomi redmi note 14 pro 5g
# xiaomi redmi note 14 pro plus 5g
# xiaomi redmi note 9
# zte blade a55

# %% [markdown]
# Đã chuẩn hóa tương đối tốt tên điện thoại, tuy nhiên "5g" làm một số tên khác nhau chỉ cùng một mẫu điện thoại. Điều này tùy vào nhà sản xuất, một số dòng có phân biệt mẫu 4g và 5g, một số dòng thì không.
# Giải pháp là xóa "5g" tùy chọn theo dòng. Vậy cần xác định chính xác hãng và dòng của các điện thoại này. Tiến hành xử lý thủ công để xóa 5g.

# %%
# Chữ đầu tiên trong name là brand
data['brand'] = data['name'].str.split(' ').str[0]

# %%
#Lọc danh sách thương hiệu có sản phẩm chứa "5g"
brand_5g = data.loc[data['name'].str.contains(r'\b5g\b', regex=True, na=False), 'brand'].dropna().unique()
print(brand_5g)
#Lọc tất cả sản phẩm unique thuộc các thương hiệu trong brand_5g
name_5g_brands = data.loc[data['brand'].isin(brand_5g), 'name'].dropna().unique()
name_5g_brands_sorted = sorted(name_5g_brands)

for name in name_5g_brands_sorted:
    print(name)
# Out:
# ['samsung' 'xiaomi' 'oppo' 'vivo' 'poco' 'realme' 'oneplus' 'nubia'
#  'honor' 'tecno']
# honor x5 plus
# honor x5b
# honor x5b plus
# honor x6b
# honor x7c
# honor x8b
# honor x8c
# honor x9c 5g
# honor x9c smart 5g
# nubia music
# nubia neo 2
# nubia neo 3 gt
# nubia redmagic 8s pro 5g
# nubia v60 design
# oneplus 11
# oneplus 11 5g
# oneplus 8t 5g
# oneplus nord ce 3 lite
# oppo a16
# oppo a17k
# oppo a18
# oppo a3
# oppo a38
# oppo a3x
# oppo a5 pro
# oppo a5 pro 5g
# oppo a57
# oppo a58
# oppo a58 4g
# oppo a60
# oppo a77s
# oppo a78
# oppo a79 5g
# oppo a98
# oppo a98 5g
# oppo find n2 flip
# oppo find n3
# oppo find n3 flip
# oppo find n3 flip 5g
# oppo find n5 fold
# oppo find x5 pro
# oppo find x5 pro 5g
# oppo find x8
# oppo find x8 5g
# oppo find x8 pro 5g
# oppo reno10 5g
# oppo reno10 pro plus 5g
# oppo reno11 5g
# oppo reno11 f 5g
# oppo reno11 pro 5g
# oppo reno12 5g
# oppo reno12 f
# oppo reno12 f 5g
# oppo reno12 pro 5g
# oppo reno13 5g
# oppo reno13 f
# oppo reno13 f 4g
# oppo reno13 f 5g
# oppo reno13 pro 5g
# oppo reno7
# oppo reno8 5g
# oppo reno8 pro 5g
# poco m6
# poco x5 5g
# realme 10
# realme 11
# realme 11 pro
# realme 11 pro 5g
# realme 12
# realme 13 plus 5g
# realme 14 5g
# realme 14t 5g
# realme c11
# realme c35
# realme c53
# realme c55
# realme c61
# realme c65
# realme c65s
# realme c67
# realme c75
# realme c75x
# realme note 50
# realme note 60
# realme note 60x
# samsung galaxy a05
# samsung galaxy a05s
# samsung galaxy a06
# samsung galaxy a06 5g
# samsung galaxy a12
# samsung galaxy a14
# samsung galaxy a14 5g
# samsung galaxy a15
# samsung galaxy a15 lte
# samsung galaxy a16
# samsung galaxy a16 5g
# samsung galaxy a23
# samsung galaxy a23 5g
# samsung galaxy a24
# samsung galaxy a25 5g
# samsung galaxy a26 5g
# samsung galaxy a32
# samsung galaxy a33
# samsung galaxy a34 5g
# samsung galaxy a35 5g
# samsung galaxy a36 5g
# samsung galaxy a53
# samsung galaxy a53 5g
# samsung galaxy a54 5g
# samsung galaxy a55 5g
# samsung galaxy a56 5g
# samsung galaxy a73 5g
# samsung galaxy m14 5g
# samsung galaxy m15 5g
# samsung galaxy m34 5g
# samsung galaxy m35 5g
# samsung galaxy m54 5g
# samsung galaxy m55
# samsung galaxy m55 5g
# samsung galaxy note 10 plus
# samsung galaxy note 20
# samsung galaxy note 20 ultra
# samsung galaxy note 20 ultra 5g
# samsung galaxy s20 fe
# samsung galaxy s20 plus
# samsung galaxy s21 5g
# samsung galaxy s21 fe
# samsung galaxy s21 fe 5g
# không quan tâm các mẫu chỉ tồn tại một phiên bản trong data, không gây khó hiểu (honor, nubia, oneplus), giữ lại toàn bộ các dòng có phân biệt rõ rệt giữa 4g và 5g (tecno, vivo).

# %%
# oppo: A series, Reno series, F series, Note series-> giữ lại; Find series -> bỏ
# Lọc các dòng có brand là "oppo" và name chứa "find"
data.loc[(data['brand'].str == 'oppo') & (data['name'].str.contains(r'\bfind\b', regex=True, na=False)), 'name'] = \
    data.loc[(data['brand'].str == 'oppo') & (data['name'].str.contains(r'\bfind\b', regex=True, na=False)), 'name'] \
    .str.replace(r'\b5g\b', '', regex=True) \
    .str.replace(r'\s+', ' ', regex=True) \
    .str.strip()

# %%
# samsung: A series, M series -> giữ lại; S series, Note series, Z flip series, Z fold series -> bỏ
# Điều kiện: Chỉ chọn thương hiệu "samsung" và loại trừ A series, M series
condition = (data['brand'] == 'samsung') & ~data['name'].str.contains(r'\ba\d+|\bm\d+', regex=True, na=False)
# Cập nhật dữ liệu: Xóa "5g" và chuẩn hóa khoảng trắng
data.loc[condition, 'name'] = data.loc[condition, 'name'].str.replace(r'\b5g\b', '', regex=True).str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
# xiaomi: redmi, redmi note -> giữ lại; xiaomi -> bỏ
# Điều kiện: Chỉ áp dụng cho thương hiệu "xiaomi" và lọc các sản phẩm có số (không phải dòng redmi, redmi note, poco)
condition = (data['brand'] == 'xiaomi') & data['name'].str.match(r'\bxiaomi \d+[a-z]*\b', na=False)

# Xóa từ "5g" trong name của các dòng thỏa mãn điều kiện
data.loc[condition, 'name'] = data.loc[condition, 'name'].str.replace(r'\b5g\b', '', regex=True).str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# # Xử lí missing values

# %%
data.isnull().sum()
# Out:
# name                     0
# brand                    0
# color                    1
# condition               35
# price_old                0
# price_new               26
# image                    0
# warranty               322
# CPU                    136
# RAM                    226
# capacity                22
# time                   442
# battery                  3
# screen_size              5
# operating_system      2019
# display_technology     697
# screen_resolution      113
# SIM                     44
# size                    67
# weight                1203
# bluetooth              279
# refresh_rate          2001
# GPU                   1818
# dtype: int64

# %% [markdown]
# Khi cùng một model điện thoại (trong bài là "name"), các yếu tố "CPU", "time", "battery", "screen_size", "operating_system", "display_technology", "screen_resolution", "SIM", "size", "weight", "bluetooth", "refresh_rate", "GPU" thường không đổi chỉ trừ một số phiên bản giới hạn. Vậy có thể điền các giá trị này nếu bị thiếu dựa vào "name".

# %%
for name_value, group in data.groupby('name'):
    total = len(group)
    columns_to_check = ["CPU", "time", "battery", "screen_size", "operating_system", 
                    "display_technology", "screen_resolution", "SIM", "size", "weight", "bluetooth", 
                    "refresh_rate", "GPU"]
    
    for column in columns_to_check:
        missing = group[column].isna().sum()
        ratio = missing / total

        if 0 < ratio < 1:
            # Lấy giá trị đầu tiên không bị thiếu trong nhóm
            value = group[column].dropna().iloc[0]
            # Gán lại cho các dòng bị thiếu trong nhóm đó
            data.loc[(data['name'] == name_value) & (data[column].isna()), column] = value

# %% [markdown]
# Riêng với RAM và capacity thì có thể thay đổi tùy vào phiên bản điện thoại, vậy có thể kiểm tra xem "name" đó có bao nhiêu giá trị "RAM" và "capacity" duy nhất. Nếu chỉ có một tức là mẫu này chỉ có một phiên bản, vậy hoàn toàn có thể điền thiếu. Nếu có nhiều hơn một phiên bản, vậy dữ liệu này không thể điền, chỉ có thể drop

# %%
for name_value, group in data.groupby('name'):
    # Kiểm tra số lượng phiên bản dựa trên RAM và capacity
    unique_ram = group["RAM"].nunique()
    unique_capacity = group["capacity"].nunique()

    # Điền RAM nếu chỉ có một phiên bản
    if unique_ram == 1:
        ram_value = group["RAM"].dropna().iloc[0]
        data.loc[(data['name'] == name_value) & (data["RAM"].isna()), "RAM"] = ram_value
    
    # Điền capacity nếu chỉ có một phiên bản
    if unique_capacity == 1:
        capacity_value = group["capacity"].dropna().iloc[0]
        data.loc[(data['name'] == name_value) & (data["capacity"].isna()), "capacity"] = capacity_value

# %%
data.isnull().sum()
# Out:
# name                     0
# brand                    0
# color                    1
# condition               35
# price_old                0
# price_new               26
# image                    0
# warranty               322
# CPU                    133
# RAM                    143
# capacity                21
# time                   207
# battery                  1
# screen_size              2
# operating_system      1407
# display_technology     400
# screen_resolution       80
# SIM                      9
# size                    21
# weight                 870
# bluetooth              254
# refresh_rate          1809
# GPU                   1730
# dtype: int64

# %%
data.shape
# Out:
# (11872, 23)

# %% [markdown]
# drop mọi thuộc tính thiếu price_new, RAM, capacity

# %%
data = data.dropna(subset=['price_new'])
data = data.dropna(subset=["RAM", "capacity"])

# %% [markdown]
# đối với condition, warranty không thu thập được, mặc định là "Cũ" và "0 tháng" (không có bảo hành).

# %%
data['condition'] = data['condition'].replace('', pd.NA).fillna('Cũ')
data['warranty'] = data['warranty'].replace('', pd.NA).fillna('0 tháng')

# %%
data.isnull().sum()
# Out:
# name                     0
# brand                    0
# color                    1
# condition                0
# price_old                0
# price_new                0
# image                    0
# warranty                 0
# CPU                     17
# RAM                      0
# capacity                 0
# time                   181
# battery                  1
# screen_size              1
# operating_system      1278
# display_technology     273
# screen_resolution       60
# SIM                      9
# size                    21
# weight                 844
# bluetooth              234
# refresh_rate          1666
# GPU                   1614
# dtype: int64

# %% [markdown]
# Tất cả missing ratio hiện tại đều là 100% theo name

# %%
missing_operating_system_counts = data[data['operating_system'].isna()].groupby('name').size()
total_counts = data.groupby('name').size()

# Tính tỉ lệ thiếu
missing_ratio = (missing_operating_system_counts / total_counts) * 100

# In các dòng bị thiếu
result = pd.DataFrame({'Missing Count': missing_operating_system_counts, 'Missing Ratio (%)': missing_ratio}).dropna()
print(result)
# Out:
#                              Missing Count  Missing Ratio (%)
# name
# honor x5 plus                          3.0              100.0
# honor x8b                              1.0              100.0
# itel it2600                            8.0              100.0
# itel it9310                            4.0              100.0
# masstel fami 50 4g                   116.0              100.0
# masstel fami 60s 4g                   31.0              100.0
# masstel izi 10                       137.0              100.0
# masstel izi 30 4g                      1.0              100.0
# masstel izi t2 4g                      1.0              100.0
# masstel izi t6 4g                     81.0              100.0
# masstel lux 10                         1.0              100.0
# mobell f209                           89.0              100.0
# mobell f309 4g                       146.0              100.0
# mobell m239 4g                       332.0              100.0
# mobell m331 4g                        65.0              100.0
# mobell m539                           79.0              100.0
# mobell rock 4                          4.0              100.0
# nokia c20                              2.0              100.0
# nubia music                            1.0              100.0
# oppo a58                              16.0              100.0
# oppo a98                               1.0              100.0
# oppo a98 5g                            7.0              100.0
# oppo find n3 flip 5g                  29.0              100.0
# oppo reno8 5g                          1.0              100.0
# realme 10                              2.0              100.0
# realme 11 pro 5g                       1.0              100.0
# realme note 50                        37.0              100.0
# samsung galaxy a05s                   39.0              100.0
# samsung galaxy a14 5g                  1.0              100.0
# samsung galaxy a24                     3.0              100.0
# samsung galaxy m54 5g                  9.0              100.0
# samsung galaxy s21 fe                  8.0              100.0
# samsung galaxy s23                     4.0              100.0
# sony xperia 10v                        1.0              100.0
# tcl 406s                               4.0              100.0
# xiaomi redmi note 11s                  1.0              100.0
# xiaomi redmi note 12 pro 5g            1.0              100.0
# xiaomi redmi note 13                   5.0              100.0
# xiaomi redmi note 13 pro 5g            6.0              100.0

# %% [markdown]
# Đối với operating_system thường sẽ phụ thuộc vào brand và series. Do trong name đã có sẵn brand, vậy dò các name có độ trùng khớp cao (khả năng cao là cùng series) để điền thiếu.

# %%
from fuzzywuzzy import process

# Lấy danh sách 'name' duy nhất có hệ điều hành
unique_names_os = data.dropna(subset=['operating_system'])[['name', 'operating_system']].drop_duplicates().set_index('name').to_dict()['operating_system']

# Lọc danh sách các tên duy nhất cần điền
missing_names = data.loc[data['operating_system'].isna(), 'name'].unique()

# Tạo ánh xạ giữa tên bị thiếu và tên có hệ điều hành gần nhất (chỉ giữ tên có độ trùng khớp > 80)
name_match_mapping = {
    name: match for name, (match, score) in 
    ((name, process.extractOne(name, unique_names_os.keys())) for name in missing_names) if score > 80
}

# Gán hệ điều hành dựa trên tên gần nhất
data.loc[data['operating_system'].isna(), 'operating_system'] = data['name'].map(lambda x: unique_names_os.get(name_match_mapping.get(x, x), None))

# Tạo bảng thống kê tỷ lệ thiếu
missing_operating_system_counts = data[data['operating_system'].isna()].groupby('name').size()
total_counts = data.groupby('name').size()
missing_ratio = (missing_operating_system_counts / total_counts) * 100

result = pd.DataFrame({'Missing Count': missing_operating_system_counts, 'Missing Ratio (%)': missing_ratio}).dropna()
print(result)
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#                  Missing Count  Missing Ratio (%)
# name
# itel it2600                8.0              100.0
# itel it9310                4.0              100.0
# mobell f209               89.0              100.0
# mobell m539               79.0              100.0
# mobell rock 4              4.0              100.0
# sony xperia 10v            1.0              100.0
# tcl 406s                   4.0              100.0

# %% [markdown]
# Các dòng điện thoại bị thiếu ở trên đều theo hệ điều hành Android

# %%
# gán các giá trị còn lại theo brand
data['operating_system'] = data['operating_system'].replace('', pd.NA).fillna('Android')

# %% [markdown]
# Đối với GPU, có thể do điện thoại không có hoặc nhà sản xuất không công bố

# %%
# đặt mặc định là 'Unknown'
data['GPU'] = data['GPU'].fillna('Unknown')

# %%
# Xóa các dữ liệu bị thiếu không đáng kể
data = data.dropna(subset=['CPU'])
data = data.dropna(subset=['price_new'])
data = data.dropna(subset=['size'])
data = data.dropna(subset=['screen_size'])

# %% [markdown]
# Chuẩn hóa screen_size

# %%
print(data['screen_size'].unique())
# Out:
# ['6.7 inches' '6.8 inches' '6.1 inches' '6.4 inches' '7.82 inches'
#  '5.5 inches' '7.6 inches' '6.9 inches' '6.6 inches' '6.56 inches'
#  '6.3 inches' '6.74 inches' '6.67 inches' '5.4 inches' '5.8 inches'
#  '6.62 inches' '4.7 inches' '6.36 inches' '6.59 inches' '6.5 inches'
#  '6.72 inches' '6.73 inches' '6.78 inches' '6.66 inches' '6.2 inches'
#  '6.55 inches' '6.64 inches' '6.79 inches' '6.28 inches' '6.88 inches'
#  '6.52 inches' '6.44 inches' '6.53 inches' '6.51 inches' '2.4 inches'
#  '6.745 inches' '2.0 inches' '8.12 inches' 'Chính 6.7" & Phụ 3.4"' '6.56"'
#  '1.77"' '6.2"' '6.4"' '6.7"' '6.8"' '6.6"' '6.5"' 'Chính 7.6" & Phụ 6.3"'
#  '6.73"' '6.1"' '1.8"' '6.36"' '2"' '6.67"' '6.79"' '6.71"' '6.88 "'
#  '6.43"' '6.72"' '2.4"' '6.74"' '2.31"' '6.68 "' '6.9"' '6.64"' '2.8"'
#  '6.745 "' 'Chính 6.8" & Phụ 3.26"' '5.4"' '6.78"' '6.3"' '6.59"' '6.83"'
#  '6.77 "']

# %% [markdown]
# Đối với refresh_rate mặc định là 60Hz đối với điện thoại cảm ứng (màn hình lớn hơn 3 inch), 30Hz đối với điện thoại không cảm ứng (màn hình nhỏ hơn 3 inch)

# %%
data['screen_size'] = data['screen_size'].apply(
    lambda x: x.split('&')[0].split('Chính')[1].strip() 
    if isinstance(x, str) and 'Chính' in x and len(x.split('Chính')) > 1
    else x if isinstance(x, str) else None
)

data['screen_size'] = data['screen_size'].apply(lambda x: (
    float(re.search(r'(\d+\.?\d*)', str(x)).group(1))
    if isinstance(x, str) and re.search(r'(\d+\.?\d*)', str(x))
    else None
))

# %%
print(data['screen_size'].unique())
# Out:
# [6.7   6.8   6.1   6.4   7.82  5.5   7.6   6.9   6.6   6.56  6.3   6.74
#  6.67  5.4   5.8   6.62  4.7   6.36  6.59  6.5   6.72  6.73  6.78  6.66
#  6.2   6.55  6.64  6.79  6.28  6.88  6.52  6.44  6.53  6.51  2.4   6.745
#  2.    8.12  1.77  1.8   6.71  6.43  2.31  6.68  2.8   6.83  6.77 ]

# %%
data.loc[data['refresh_rate'].isna(), 'refresh_rate'] = data.apply(
    lambda row: 60 if row['screen_size'] > 3 else 30, axis=1
)

# %%
data.isnull().sum()
# Out:
# name                    0
# brand                   0
# color                   1
# condition               0
# price_old               0
# price_new               0
# image                   0
# warranty                0
# CPU                     0
# RAM                     0
# capacity                0
# time                  162
# battery                 0
# screen_size             0
# operating_system        0
# display_technology    253
# screen_resolution      46
# SIM                     2
# size                    0
# weight                820
# bluetooth             210
# refresh_rate            0
# GPU                     0
# dtype: int64

# %% [markdown]
# các giá trị còn thiếu còn lại không đáng kể -> drop

# %%
data.dropna(inplace=True)

# %%
# Xuất DataFrame ra file CSV
data.to_csv('updated_data.csv', index=False, encoding='utf-8-sig')
